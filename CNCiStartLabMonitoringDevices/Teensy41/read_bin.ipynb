# %%
# read dataLog00000.TXT file

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import struct
from pathlib import Path
import os
import json

import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
def get_values_from_bin_file(bin_file_pointer, nr_bytes, format): 
    #----------------------timestamp
    data_byte_1 = bin_file_pointer.read(nr_bytes)
    if len(data_byte_1)==0:
        return False,bin_file_pointer
    value, = struct.unpack(format, data_byte_1)
        
    return value,bin_file_pointer

def get_params_from_bin_file(bin_file_pointer,nr_sources,sources_names):
    # create dictionary for data from each source
    sources_dic = {}
    # for each source get sample rate, sensitivity, sample group
    for source in sources_names:
        freq_set,bin_file_pointer = get_values_from_bin_file(bin_file_pointer, 2, '>H')
        sensitivity,bin_file_pointer = get_values_from_bin_file(bin_file_pointer, 2, '>H')
        sensitivity = sensitivity/1000
        scale,bin_file_pointer = get_values_from_bin_file(bin_file_pointer, 2, '>H')
        sample_group_nr,bin_file_pointer = get_values_from_bin_file(bin_file_pointer, 2, '>H')
        sources_dic[source] = {'freq_set':freq_set, 'sensitivity':sensitivity, 'sample_group_nr':sample_group_nr, 'scale':scale}

    return sources_dic,bin_file_pointer

def get_logger_file_nr_from_bin_file(filename: str):
    # find 'id_' and read the number after it
    for i in range(len(filename)):
        if filename[i:i+3] == 'id_':
            logger_id = int(filename[i+3:i+7])
            break
    # find 'nr_' and read the number after it
    for i in range(len(filename)):
        if filename[i:i+3] == 'nr_':
            logger_file_nr = int(filename[i+3:i+7])
            break
    return [logger_id, logger_file_nr]

def get_header_from_bin_file(bin_file_pointer):
    # read header until '/&/' is found
    header = ''
    while True:
        data_byte_1,bin_file_pointer = get_values_from_bin_file(bin_file_pointer, 1, 'c')
        if data_byte_1 == b'':
            print('End of file reached')
            break
        if data_byte_1 == b'/':
            data_byte_2,bin_file_pointer = get_values_from_bin_file(bin_file_pointer, 1, 'c')
            if data_byte_2 == b'&':
                data_byte_3,bin_file_pointer = get_values_from_bin_file(bin_file_pointer, 1, 'c')
                if data_byte_3 == b'/':
                    break
        header += data_byte_1.decode('utf-8')

    # split header with ',' into list of strings
    header = header.split(',')

    return header,bin_file_pointer

def create_logger_id_parameters_dict(logger_id : int,sources_names : list[str], sources_units_dict: dict, curr_file_sources_dic: dict):
    dict_logger_id = {
        logger_id: {
            'dictionary_type':'dataset-from-logger_id',
            'value_type':'dictionary',
            'labels':{
                'dictionary_type':'dataset_parameter',
                'value_type':'dictionary-of-the-labels',
                'value_unit':'',
                'value':{
                    0: {
                        'dictionary_type': 'label',
                        'value_type': 'dictionary-of-label',
                        'value_unit': '',
                        'description': 'Label-0',
                        'nr_files': 0,
                    },
                    1: {
                        'dictionary_type': 'label',
                        'value_type': 'dictionary-of-label',
                        'value_unit': '',
                        'description': 'Label-1',
                        'nr_files': 0,
                    },
                    2: {
                        'dictionary_type': 'label',
                        'value_type': 'dictionary-of-label',
                        'value_unit': '',
                        'description': 'Label-2',
                        'nr_files': 0,
                    }
                },
                'description':'dataset-labels',
            },
            'nr_files':{
                'dictionary_type':'dataset_parameter',
                'value_type':'int',
                'value_unit':'',
                'value':0,
                'description':'number-of-files',
            },
            'total_measured_time':{
                'dictionary_type':'dataset_parameter',
                'value_type':'int',
                'value_unit':'seconds',
                'value':0,
                'description':'total-measured-time-of-the-dataset',
            },
            'sources':{
                'dictionary_type':'dataset_parameter',
                'value_type':'dictionary-of-dictionaries-sources',
                'value_unit':'',
                'value':{
                    source: {
                        'dictionary_type': 'source',
                        'value_type': 'dictionary-of-source parameters',
                        **{f"value_unit": sources_units_dict[source_key] for source_key in sources_units_dict.keys() if source_key in source},
                        'sampling_frequency_set': {
                            'dictionary_type': 'source_parameter',
                            'value_type': 'int',
                            'value_unit': '[Hz]',
                            'value': curr_file_sources_dic[source]['freq_set'],
                            'description': 'sampling-frequency-set-in-the-logger',
                        },
                        'sampling_frequency_real': {
                            'dictionary_type': 'source_parameter',
                            'value_type': 'int',
                            'value_unit': '[Hz]',
                            'value': 0,
                            'description': 'real-sampling-frequency-of-the-source, number-of-samples-per-second',
                        },
                        'samples_nr': {
                            'dictionary_type': 'source_parameter',
                            'value_type': 'int',
                            'value_unit': '',
                            'value': 0,
                            'description': 'number-of-samples',
                        },
                        'samples_nr_bytes': {
                            'dictionary_type': 'source_parameter',
                            'value_type': 'int',
                            'value_unit': 'bytes',
                            'value': -1,
                            'description': 'number-of-bytes-of-each-sample',
                        },
                        'scale': {
                            'dictionary_type': 'source_parameter',
                            'value_type': 'int',
                            **{f"value_unit": sources_units_dict[source_key] for source_key in sources_units_dict.keys() if source_key in source},
                            'value': curr_file_sources_dic[source]['scale'],
                            'description': 'scale-of-the-source',
                        }
                    } for source in sources_names       
                },
            }
        }
    } 

    return dict_logger_id

def remove_chars_from_string(filename: str,char_to_remove: list[str]):
    for char_to_remove in char_to_remove:
        filename = filename.replace(char_to_remove, "")
    return filename

def sort_list(list1, list2):
 
    zipped_pairs = zip(list2, list1)
 
    z = [x for _, x in sorted(zipped_pairs)]
 
    return z

def list2wave(readings_list,wave_wave_file_path_and_name,nr_channels,freq,sample_size):

    np_readings_list=np.array(readings_list)

    sample_size=2
    
    obj = wave.open(wave_wave_file_path_and_name,'w')
    obj.setnchannels(nr_channels)
    obj.setsampwidth(sample_size)
    obj.setframerate(freq)
    for sample in np_readings_list:
        if sample_size==2:
            aux_data = struct.pack('<h', sample)
        elif sample_size==4:    
            aux_data = struct.pack('<f', np.float32(float(sample)))
        else:
            print("Warning! Sample size not supported to make correct Wave files! See list2wave function")
            return

        obj.writeframesraw( aux_data )
    obj.close()

# %%
dataset_parameters_dict={}

sources_units_dict={'acc':'[mg]','mic':'[dB]'}

#print sources_units keys
#print(sources_units_dict.keys())

main_dfs_list=[]

dataset_sources_names=[]
dataset_sources_flags_names=[]

for dirname, _, filenames in (os.walk("C:/Users/ricar/OneDrive - Universidade de Lisboa/ObsidianVaults/KeeperOfKnowledge_ObsVault/1_University/1_1_Thesis/1_1_10_Datasets/CNC_iStartLab_Main/CAMs_Gcode_Data/6666Hz/Facing0_0010/Raw")):
    txt_files = [f for f in filenames if f.endswith('.TXT')]
    print(txt_files)
    for filename in (txt_files):
        print(filename)

        # Open the binary file for reading

        bin_file_pointer = open(os.path.join(dirname, filename), "rb")
        important_input_vals=[]

        logger_ids = get_logger_file_nr_from_bin_file(filename)

        curr_file_logger_id = logger_ids[0]
        curr_file_logger_file_nr = logger_ids[1]

        #get header from bin file
        curr_file_header,_ = get_header_from_bin_file(bin_file_pointer)
        #get sources from header (first element is 'timestamp', second is the button , third is flags source) the rest the source data
        curr_file_sources_names = curr_file_header[3:]
        curr_file_nr_sources = int(len(curr_file_sources_names))

        curr_file_sources_dic,_ = get_params_from_bin_file(bin_file_pointer,curr_file_nr_sources,curr_file_sources_names)
            
        # get the maximum sample group number from all the sources
        max_sample_group_nr = 0
        for source in curr_file_sources_names:
            if curr_file_sources_dic[source]['sample_group_nr'] > max_sample_group_nr:
                max_sample_group_nr = curr_file_sources_dic[source]['sample_group_nr']
        
        curr_file_sources_flags_names = ['flag_' + source for source in curr_file_sources_names]

        # create dataframe with the timestamp, logger_id, file_nr and sources names
        columns_list = ['timestamp', 'logger_id','logger_file_nr','label']
        columns_list.extend(curr_file_sources_flags_names)
        columns_list.extend(curr_file_sources_names)
        df = pd.DataFrame(columns=columns_list)

        dataset_sources_names.extend(curr_file_sources_names)
        dataset_sources_flags_names.extend(curr_file_sources_flags_names)
        curr_file_sources_counter = {source: 0 for source in curr_file_sources_names}

        # create dictionary with the flags of the sources
        curr_file_sources_vals_dict = {
            source: [] for source in curr_file_sources_names
        }

        curr_file_repeated_params_dict = {    
            flag_name: [] for flag_name in curr_file_sources_flags_names
        }
        curr_file_repeated_params_dict['timestamp'] = []
        curr_file_repeated_params_dict['logger_id'] = []
        curr_file_repeated_params_dict['logger_file_nr'] = []
        curr_file_repeated_params_dict['label'] = []
        
        while (1):
    
            curr_row_timestamp,_ = get_values_from_bin_file(bin_file_pointer, 4, '>L')
            if curr_row_timestamp is False:
                break

            curr_row_label,_ = get_values_from_bin_file(bin_file_pointer, 1, '>B')

            #----------------------dataset_sensor_flags
            curr_row_flags,_ = get_values_from_bin_file(bin_file_pointer, 1, '>B')
            curr_row_flags = [bool(curr_row_flags >> i & 1) for i in range(curr_file_nr_sources)]

            for sample_nr in range(max_sample_group_nr):
                for i,flag_name in enumerate(curr_file_sources_flags_names):
                    curr_file_repeated_params_dict[flag_name].append(curr_row_flags[i])
                curr_file_repeated_params_dict['timestamp'].append(curr_row_timestamp)
                curr_file_repeated_params_dict['logger_id'].append(curr_file_logger_id)
                curr_file_repeated_params_dict['logger_file_nr'].append(curr_file_logger_file_nr)
                curr_file_repeated_params_dict['label'].append(curr_row_label)

            # counter of samples for each source
            sample_group_nr = {source: 0 for source in curr_file_sources_names}

            for sample_nr in range(max_sample_group_nr):
                for i,source in enumerate(curr_file_sources_names):
                    if (curr_row_flags[i] and sample_group_nr[source] < curr_file_sources_dic[source]['sample_group_nr']):
                        aux_sources_vals,_ = get_values_from_bin_file(bin_file_pointer, 2, '>h')
                        curr_file_sources_vals_dict[source].append(round(aux_sources_vals*curr_file_sources_dic[source]['sensitivity'],4))
                        #curr_file_sources_vals_dict[source].append(aux_sources_vals)
                        # increment sample_group_nr for the source
                        sample_group_nr[source] += 1
                        curr_file_sources_counter[source] += 1
                    else:
                        curr_file_sources_vals_dict[source] = (np.nan)
                        
        aux_df = pd.DataFrame({**curr_file_repeated_params_dict, **curr_file_sources_vals_dict})
        df = pd.concat([df, aux_df], ignore_index=True)
        # print first 5 rows of dataframe
        print(df.head())

        bin_file_pointer.close()
        
        unique_file_labels = pd.unique(df['label'])
        time_curr_file = (df['timestamp'][len(df)-1]-df['timestamp'][0])/1000
        main_dfs_list.append(df)

        # check if logger_id is already in dataset_parameters_dict
        if curr_file_logger_id not in dataset_parameters_dict.keys():
            aux_dataset_parameters_dict = create_logger_id_parameters_dict(curr_file_logger_id,curr_file_sources_names,sources_units_dict,curr_file_sources_dic)
            dataset_parameters_dict.update(aux_dataset_parameters_dict)
        
        # update dataset_parameters_dict
        # create new label key if it doesn't exist in dataset_parameters_dict
        for label in unique_file_labels:
            if label not in dataset_parameters_dict[curr_file_logger_id]['labels']['value'].keys():
                new_label_dict = { label: { 'nr_files': 0 } }
                dataset_parameters_dict[curr_file_logger_id]['labels']['value'].update(dict(new_label_dict))
            dataset_parameters_dict[curr_file_logger_id]['labels']['value'][label]['nr_files'] = dataset_parameters_dict[curr_file_logger_id]['labels']['value'][label]['nr_files'] + 1
        dataset_parameters_dict[curr_file_logger_id]['nr_files']['value'] = dataset_parameters_dict[curr_file_logger_id]['nr_files']['value'] + 1
        dataset_parameters_dict[curr_file_logger_id]['total_measured_time']['value'] = dataset_parameters_dict[curr_file_logger_id]['total_measured_time']['value'] + time_curr_file
        for source in curr_file_sources_names:
            dataset_parameters_dict[curr_file_logger_id]['sources']['value'][source]['sampling_frequency_real']['value'] = dataset_parameters_dict[curr_file_logger_id]['sources']['value'][source]['sampling_frequency_real']['value'] + round(curr_file_sources_counter[source]/time_curr_file,4)
            dataset_parameters_dict[curr_file_logger_id]['sources']['value'][source]['samples_nr']['value'] = dataset_parameters_dict[curr_file_logger_id]['sources']['value'][source]['samples_nr']['value'] + curr_file_sources_counter[source]




# divide values of dataset_parameters_dict by nr_files for all the logger_ids
for logger_id in dataset_parameters_dict.keys():
    for source in dataset_parameters_dict[logger_id]['sources']['value'].keys():
        dataset_parameters_dict[logger_id]['sources']['value'][source]['sampling_frequency_real']['value'] = dataset_parameters_dict[logger_id]['sources']['value'][source]['sampling_frequency_real']['value']/dataset_parameters_dict[logger_id]['nr_files']['value']

# concatenate all the datasets and reset the index
main_df = pd.concat(main_dfs_list).reset_index().rename(columns={'index':'sample_index'})

main_df.columns.str.match("Unnamed")
main_df.loc[:,~main_df.columns.str.match("Unnamed")]

main_df=main_df.replace(r'^\s*$', np.nan, regex=True)
# add columns with flags for each source

# remove columns: sample_index, logger_file_nr, logger_id, timestamp, label
main_df = main_df.drop(columns=['sample_index','logger_file_nr','timestamp','label'])
# remove columns that start with 'flag_'
main_df = main_df.loc[:,~main_df.columns.str.match("flag_")]

# get the logger_id unique values
logger_ids = pd.unique(main_df['logger_id'])
# for each logger id save a csv file and a json file
for logger_id in logger_ids:
    # get the dataset_parameters_dict for the current logger_id
    logger_id_dataset_parameters_dict = dataset_parameters_dict[logger_id]
    # save the dataset_parameters_dict as a json file
    with open('label_'+str(logger_id)+'.json', 'w') as fp:
        json.dump(logger_id_dataset_parameters_dict, fp, indent=4)
    # get the sources names for the current logger_id
    logger_id_sources_names = logger_id_dataset_parameters_dict['sources']['value'].keys()
    # get the dataframe with the current logger_id
    logger_id_df = main_df[main_df['logger_id'] == logger_id]
    logger_id_df.to_csv('label_'+str(logger_id)+'.csv',index=False, columns = logger_id_sources_names)


#melted_dataset_df = main_df.melt(id_vars=id_vars,value_vars=value_vars,var_name='source',value_name='readings')
# Out:
# ['dataLog_id_0011_nr_0000.TXT', 'dataLog_id_0011_nr_0001.TXT', 'dataLog_id_0011_nr_0002.TXT', 'dataLog_id_0011_nr_0003.TXT', 'dataLog_id_0011_nr_0004.TXT', 'dataLog_id_0011_nr_0005.TXT', 'dataLog_id_0011_nr_0006.TXT', 'dataLog_id_0011_nr_0007.TXT', 'dataLog_id_0012_nr_0000.TXT', 'dataLog_id_0012_nr_0001.TXT', 'dataLog_id_0012_nr_0002.TXT', 'dataLog_id_0012_nr_0003.TXT', 'dataLog_id_0012_nr_0004.TXT', 'dataLog_id_0012_nr_0005.TXT', 'dataLog_id_0012_nr_0006.TXT', 'dataLog_id_0020_nr_0000.TXT', 'dataLog_id_0020_nr_0001.TXT', 'dataLog_id_0020_nr_0002.TXT', 'dataLog_id_0020_nr_0003.TXT', 'dataLog_id_0020_nr_0004.TXT', 'dataLog_id_0020_nr_0005.TXT', 'dataLog_id_0020_nr_0006.TXT', 'dataLog_id_0020_nr_0007.TXT', 'dataLog_id_0020_nr_0008.TXT', 'dataLog_id_0020_nr_0009.TXT', 'dataLog_id_0020_nr_0010.TXT', 'dataLog_id_0020_nr_0011.TXT', 'dataLog_id_0020_nr_0012.TXT', 'dataLog_id_0020_nr_0013.TXT', 'dataLog_id_0020_nr_0014.TXT', 'dataLog_id_0020_nr_0015.TXT', 'dataLog_id_0020_nr_0016.TXT', 'dataLog_id_0020_nr_0017.TXT', 'dataLog_id_0020_nr_0018.TXT', 'dataLog_id_0020_nr_0019.TXT', 'dataLog_id_0020_nr_0020.TXT', 'dataLog_id_0020_nr_0021.TXT', 'dataLog_id_0020_nr_0022.TXT', 'dataLog_id_0020_nr_0023.TXT', 'dataLog_id_0020_nr_0024.TXT', 'dataLog_id_0021_nr_0000.TXT', 'dataLog_id_0021_nr_0001.TXT', 'dataLog_id_0021_nr_0002.TXT', 'dataLog_id_0021_nr_0003.TXT', 'dataLog_id_0021_nr_0004.TXT', 'dataLog_id_0021_nr_0005.TXT', 'dataLog_id_0021_nr_0006.TXT', 'dataLog_id_0021_nr_0007.TXT', 'dataLog_id_0021_nr_0008.TXT', 'dataLog_id_0021_nr_0009.TXT', 'dataLog_id_0021_nr_0010.TXT', 'dataLog_id_0021_nr_0011.TXT', 'dataLog_id_0021_nr_0012.TXT', 'dataLog_id_0021_nr_0013.TXT', 'dataLog_id_0021_nr_0014.TXT', 'dataLog_id_0021_nr_0015.TXT', 'dataLog_id_0021_nr_0016.TXT', 'dataLog_id_0021_nr_0017.TXT', 'dataLog_id_0021_nr_0018.TXT', 'dataLog_id_0021_nr_0019.TXT', 'dataLog_id_0021_nr_0020.TXT', 'dataLog_id_0021_nr_0021.TXT', 'dataLog_id_0021_nr_0022.TXT', 'dataLog_id_0022_nr_0000.TXT', 'dataLog_id_0022_nr_0001.TXT', 'dataLog_id_0022_nr_0002.TXT', 'dataLog_id_0022_nr_0003.TXT', 'dataLog_id_0022_nr_0004.TXT', 'dataLog_id_0022_nr_0005.TXT', 'dataLog_id_0022_nr_0006.TXT', 'dataLog_id_0022_nr_0007.TXT', 'dataLog_id_0022_nr_0008.TXT', 'dataLog_id_0022_nr_0009.TXT', 'dataLog_id_0022_nr_0010.TXT', 'dataLog_id_0022_nr_0011.TXT', 'dataLog_id_0022_nr_0012.TXT', 'dataLog_id_0022_nr_0013.TXT', 'dataLog_id_0022_nr_0014.TXT', 'dataLog_id_0022_nr_0015.TXT', 'dataLog_id_0022_nr_0016.TXT', 'dataLog_id_0022_nr_0017.TXT', 'dataLog_id_0022_nr_0018.TXT', 'dataLog_id_0022_nr_0019.TXT', 'dataLog_id_0023_nr_0000.TXT', 'dataLog_id_0023_nr_0001.TXT', 'dataLog_id_0023_nr_0002.TXT', 'dataLog_id_0023_nr_0003.TXT', 'dataLog_id_0023_nr_0004.TXT', 'dataLog_id_0023_nr_0005.TXT', 'dataLog_id_0023_nr_0006.TXT', 'dataLog_id_0023_nr_0007.TXT', 'dataLog_id_0023_nr_0008.TXT', 'dataLog_id_0023_nr_0009.TXT', 'dataLog_id_0023_nr_0010.TXT', 'dataLog_id_0023_nr_0011.TXT', 'dataLog_id_0023_nr_0012.TXT', 'dataLog_id_0023_nr_0013.TXT', 'dataLog_id_0024_nr_0000.TXT', 'dataLog_id_0024_nr_0001.TXT', 'dataLog_id_0025_nr_0000.TXT', 'dataLog_id_0025_nr_0001.TXT', 'dataLog_id_0025_nr_0002.TXT', 'dataLog_id_0025_nr_0003.TXT', 'dataLog_id_0025_nr_0004.TXT', 'dataLog_id_0025_nr_0005.TXT', 'dataLog_id_0025_nr_0006.TXT', 'dataLog_id_0025_nr_0007.TXT', 'dataLog_id_0025_nr_0008.TXT', 'dataLog_id_0025_nr_0009.TXT', 'dataLog_id_0025_nr_0010.TXT', 'dataLog_id_0025_nr_0011.TXT', 'dataLog_id_0025_nr_0012.TXT', 'dataLog_id_0025_nr_0013.TXT', 'dataLog_id_0025_nr_0014.TXT', 'dataLog_id_0025_nr_0015.TXT', 'dataLog_id_0025_nr_0016.TXT', 'dataLog_id_0026_nr_0000.TXT', 'dataLog_id_0026_nr_0001.TXT', 'dataLog_id_0026_nr_0002.TXT', 'dataLog_id_0026_nr_0003.TXT', 'dataLog_id_0026_nr_0004.TXT', 'dataLog_id_0026_nr_0005.TXT', 'dataLog_id_0026_nr_0006.TXT', 'dataLog_id_0026_nr_0007.TXT', 'dataLog_id_0026_nr_0008.TXT', 'dataLog_id_0026_nr_0009.TXT', 'dataLog_id_0026_nr_0010.TXT', 'dataLog_id_0026_nr_0011.TXT', 'dataLog_id_0026_nr_0012.TXT',  ...
# dataLog_id_0011_nr_0000.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0       899        11              0     0       True       True       True  \
# 1       899        11              0     0       True       True       True
# 2       899        11              0     0       True       True       True
# 3       899        11              0     0       True       True       True
# 4       899        11              0     0       True       True       True
#
#     acc_x   acc_y    acc_z
# 0 -39.528  -7.808  942.328
# 1 -39.040  -9.272  947.208
# 2 -47.824 -17.080  964.776
# 3 -35.136  -9.272  973.560
# 4 -35.624  -4.392  983.808
# dataLog_id_0011_nr_0001.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0     60995        11              1     0       True       True       True  \
# 1     60995        11              1     0       True       True       True
# 2     60995        11              1     0       True       True       True
# 3     60995        11              1     0       True       True       True
# 4     60995        11              1     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0 -135.664  421.632  970.632
# 1 -147.864  379.176  658.800
# 2  -73.688  259.616  396.744
# 3    7.808   98.088  238.144
# 4   56.120 -122.976  303.048
# dataLog_id_0011_nr_0002.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    121038        11              2     0       True       True       True  \
# 1    121038        11              2     0       True       True       True
# 2    121038        11              2     0       True       True       True
# 3    121038        11              2     0       True       True       True
# 4    121038        11              2     0       True       True       True
#
#       acc_x    acc_y    acc_z
# 0 -1054.080   81.496  -89.304
# 1  -378.688 -171.776  -53.680
# 2   217.648 -115.656   36.600
# 3   650.992 -213.744  183.488
# 4   750.544 -361.120  312.808
# dataLog_id_0011_nr_0003.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    181143        11              3     0       True       True       True  \
# 1    181143        11              3     0       True       True       True
# 2    181143        11              3     0       True       True       True
# 3    181143        11              3     0       True       True       True
# 4    181143        11              3     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0 -622.200  465.552 -501.176
# 1 -604.632  205.448 -565.592
# 2 -333.304  -80.520 -338.184
# 3   43.432 -183.488   16.104
# 4  270.840 -155.184  408.456
# dataLog_id_0011_nr_0004.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    241158        11              4     0       True       True       True  \
# 1    241158        11              4     0       True       True       True
# 2    241158        11              4     0       True       True       True
# 3    241158        11              4     0       True       True       True
# 4    241158        11              4     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  -56.608 -205.936   650.504
# 1  126.880 -178.608   811.544
# 2  319.640 -101.504  1013.576
# 3  518.744 -107.360  1240.496
# 4  571.448 -189.832  1398.608
# dataLog_id_0011_nr_0005.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    301173        11              5     0       True       True       True  \
# 1    301173        11              5     0       True       True       True
# 2    301173        11              5     0       True       True       True
# 3    301173        11              5     0       True       True       True
# 4    301173        11              5     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -668.560 -327.936  1655.784
# 1 -399.184   82.960  1399.096
# 2  -40.504  316.224   985.272
# 3  -54.168  359.168   472.872
# 4 -410.896  318.664    88.328
# dataLog_id_0011_nr_0006.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    361189        11              6     0       True       True       True  \
# 1    361189        11              6     0       True       True       True
# 2    361189        11              6     0       True       True       True
# 3    361189        11              6     0       True       True       True
# 4    361189        11              6     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0 -248.392  187.880  728.584
# 1 -303.536  282.552  326.472
# 2 -356.728  233.264   25.376
# 3 -361.120   53.680  -95.160
# 4 -262.056  -74.176  -80.032
# dataLog_id_0011_nr_0007.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    421207        11              7     0       True       True       True  \
# 1    421207        11              7     0       True       True       True
# 2    421207        11              7     0       True       True       True
# 3    421207        11              7     0       True       True       True
# 4    421207        11              7     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0 -316.224  297.192  247.416
# 1 -572.424  501.176 -226.432
# 2 -602.192  372.344 -405.040
# 3 -326.960   77.104 -369.904
# 4   -9.760  -20.496 -224.480
# dataLog_id_0012_nr_0000.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0      1313        12              0     0       True       True       True  \
# 1      1313        12              0     0       True       True       True
# 2      1313        12              0     0       True       True       True
# 3      1313        12              0     0       True       True       True
# 4      1313        12              0     0       True       True       True
#
#     acc_x   acc_y    acc_z
# 0 -26.840 -18.544  945.256
# 1 -19.032 -21.960  941.840
# 2 -17.080 -31.232  940.376
# 3 -16.592 -23.912  937.936
# 4 -12.688 -16.104  938.912
# dataLog_id_0012_nr_0001.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0     61409        12              1     0       True       True       True  \
# 1     61409        12              1     0       True       True       True
# 2     61409        12              1     0       True       True       True
# 3     61409        12              1     0       True       True       True
# 4     61409        12              1     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0  -56.608  -32.208  639.280
# 1   10.248 -374.784  381.128
# 2 -136.152 -605.120  571.448
# 3 -446.520 -687.104  892.064
# 4 -486.536 -622.200  854.000
# dataLog_id_0012_nr_0002.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    121471        12              2     0       True       True       True  \
# 1    121471        12              2     0       True       True       True
# 2    121471        12              2     0       True       True       True
# 3    121471        12              2     0       True       True       True
# 4    121471        12              2     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -401.624   33.672   367.464
# 1 -472.384   23.912    37.088
# 2 -433.344 -145.424   222.040
# 3 -354.776 -448.960   776.896
# 4 -254.736 -532.408  1067.256
# dataLog_id_0012_nr_0003.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    181482        12              3     0       True       True       True  \
# 1    181482        12              3     0       True       True       True
# 2    181482        12              3     0       True       True       True
# 3    181482        12              3     0       True       True       True
# 4    181482        12              3     0       True       True       True
#
#      acc_x     acc_y     acc_z
# 0  290.848   784.704  1829.512
# 1   51.240  1016.504  1319.064
# 2 -296.216   937.936  1049.688
# 3 -328.424   493.856   879.864
# 4 -252.296  -153.232   595.360
# dataLog_id_0012_nr_0004.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    241495        12              4     0       True       True       True  \
# 1    241495        12              4     0       True       True       True
# 2    241495        12              4     0       True       True       True
# 3    241495        12              4     0       True       True       True
# 4    241495        12              4     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -193.736 -925.248  1055.544
# 1 -209.352 -511.424  1012.600
# 2  -26.840 -371.856   474.824
# 3   98.576 -395.280    75.152
# 4 -165.920 -326.960   339.160
# dataLog_id_0012_nr_0005.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    301513        12              5     0       True       True       True  \
# 1    301513        12              5     0       True       True       True
# 2    301513        12              5     0       True       True       True
# 3    301513        12              5     0       True       True       True
# 4    301513        12              5     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  433.832  880.352  1587.464
# 1   39.040  847.656  1206.824
# 2 -292.312  577.792   878.888
# 3 -255.224   24.400   579.744
# 4  -59.536 -524.600   516.304
# dataLog_id_0012_nr_0006.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    361461        12              6     0       True       True       True  \
# 1    361461        12              6     0       True       True       True
# 2    361461        12              6     0       True       True       True
# 3    361461        12              6     0       True       True       True
# 4    361461        12              6     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -107.848  -62.952  1712.880
# 1 -208.376  258.640  2595.184
# 2  134.200  656.360  3001.200
# 3  611.464  754.448  2925.072
# 4  753.472  844.728  2382.904
# dataLog_id_0020_nr_0000.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0      1490        20              0     0       True       True       True  \
# 1      1490        20              0     0       True       True       True
# 2      1490        20              0     0       True       True       True
# 3      1490        20              0     0       True       True       True
# 4      1490        20              0     0       True       True       True
#
#     acc_x   acc_y    acc_z
# 0 -19.520 -17.080  982.832
# 1 -14.152 -27.816  991.128
# 2  -6.832 -37.088  990.152
# 3 -14.152 -27.328  992.104
# 4 -26.352 -23.424  989.664
# dataLog_id_0020_nr_0001.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0     61373        20              1     0       True       True       True  \
# 1     61373        20              1     0       True       True       True
# 2     61373        20              1     0       True       True       True
# 3     61373        20              1     0       True       True       True
# 4     61373        20              1     0       True       True       True
#
#      acc_x   acc_y    acc_z
# 0  -77.592  48.312  929.640
# 1  130.784  33.184  658.800
# 2  132.736  34.648  376.248
# 3  -41.968  25.376  166.896
# 4 -321.592  -1.464   64.904
# dataLog_id_0020_nr_0002.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    121426        20              2     0       True       True       True  \
# 1    121426        20              2     0       True       True       True
# 2    121426        20              2     0       True       True       True
# 3    121426        20              2     0       True       True       True
# 4    121426        20              2     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  699.304 -281.088  1482.056
# 1  462.624 -257.176  1558.184
# 2  101.504 -115.168  1550.376
# 3 -240.584   86.864  1477.176
# 4 -441.640  255.224  1329.800
# dataLog_id_0020_nr_0003.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    181408        20              3     0       True       True       True  \
# 1    181408        20              3     0       True       True       True
# 2    181408        20              3     0       True       True       True
# 3    181408        20              3     0       True       True       True
# 4    181408        20              3     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  316.712  241.560  1390.312
# 1  244.488  214.720  1421.056
# 2  184.952   84.424  1294.176
# 3   55.632  -44.896  1041.880
# 4  -85.888 -108.336   736.880
# dataLog_id_0020_nr_0004.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    241400        20              4     0       True       True       True  \
# 1    241400        20              4     0       True       True       True
# 2    241400        20              4     0       True       True       True
# 3    241400        20              4     0       True       True       True
# 4    241400        20              4     0       True       True       True
#
#      acc_x   acc_y    acc_z
# 0 -107.848  50.264  217.648
# 1 -271.328  25.376  196.176
# 2 -413.336 -29.768  347.944
# 3 -463.112 -52.704  591.456
# 4 -341.112 -37.088  842.776
# dataLog_id_0020_nr_0005.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    301455        20              5     0       True       True       True  \
# 1    301455        20              5     0       True       True       True
# 2    301455        20              5     0       True       True       True
# 3    301455        20              5     0       True       True       True
# 4    301455        20              5     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0 -286.456  -92.232  373.808
# 1  -53.192 -210.816  403.088
# 2  193.248 -285.968  500.200
# 3  349.408 -259.616  635.376
# 4  379.176 -136.640  765.184
# dataLog_id_0020_nr_0006.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    361438        20              6     0       True       True       True  \
# 1    361438        20              6     0       True       True       True
# 2    361438        20              6     0       True       True       True
# 3    361438        20              6     0       True       True       True
# 4    361438        20              6     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  130.784  149.328  1441.064
# 1  -75.152   96.624  1059.936
# 2 -284.992   17.568   731.024
# 3 -425.048  -42.456   507.520
# 4 -417.728  -99.064   395.768
# dataLog_id_0020_nr_0007.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    421429        20              7     0       True       True       True  \
# 1    421429        20              7     0       True       True       True
# 2    421429        20              7     0       True       True       True
# 3    421429        20              7     0       True       True       True
# 4    421429        20              7     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0 -476.776 -162.992  689.544
# 1 -589.992   -7.320  652.456
# 2 -452.864   88.328  683.688
# 3 -157.136  102.968  714.920
# 4  182.512   43.920  736.392
# dataLog_id_0020_nr_0008.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    481486        20              8     0       True       True       True  \
# 1    481486        20              8     0       True       True       True
# 2    481486        20              8     0       True       True       True
# 3    481486        20              8     0       True       True       True
# 4    481486        20              8     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -487.512  157.624   572.424
# 1 -250.832  182.024   628.544
# 2   26.352  104.432   736.880
# 3  239.120   24.888   889.624
# 4  384.544  -42.944  1023.824
# dataLog_id_0020_nr_0009.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    541468        20              9     0       True       True       True  \
# 1    541468        20              9     0       True       True       True
# 2    541468        20              9     0       True       True       True
# 3    541468        20              9     0       True       True       True
# 4    541468        20              9     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -395.768  212.280  1319.552
# 1 -191.296  192.272  1318.088
# 2   63.440  121.512  1313.208
# 3  252.296   29.280  1346.392
# 4  276.696  -15.128  1417.152
# dataLog_id_0020_nr_0010.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    601462        20             10     0       True       True       True  \
# 1    601462        20             10     0       True       True       True
# 2    601462        20             10     0       True       True       True
# 3    601462        20             10     0       True       True       True
# 4    601462        20             10     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0  147.864 -325.984  779.824
# 1  -91.256 -291.824  634.888
# 2 -327.936 -116.632  613.904
# 3 -386.984   82.472  691.984
# 4 -195.688  193.248  806.664
# dataLog_id_0020_nr_0011.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    661513        20             11     0       True       True       True  \
# 1    661513        20             11     0       True       True       True
# 2    661513        20             11     0       True       True       True
# 3    661513        20             11     0       True       True       True
# 4    661513        20             11     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  504.592   62.464  1383.480
# 1  537.776    1.952  1414.712
# 2  392.352  -61.000  1483.032
# 3  127.856 -177.144  1610.400
# 4 -107.848 -284.016  1764.608
# dataLog_id_0020_nr_0012.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    721495        20             12     0       True       True       True  \
# 1    721495        20             12     0       True       True       True
# 2    721495        20             12     0       True       True       True
# 3    721495        20             12     0       True       True       True
# 4    721495        20             12     0       True       True       True
#
#      acc_x   acc_y    acc_z
# 0 -214.232 -45.872  346.480
# 1 -182.024  -3.904  212.768
# 2 -190.320  26.352  205.936
# 3 -210.328  32.696  353.312
# 4 -207.888  44.408  610.488
# dataLog_id_0020_nr_0013.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    781487        20             13     0       True       True       True  \
# 1    781487        20             13     0       True       True       True
# 2    781487        20             13     0       True       True       True
# 3    781487        20             13     0       True       True       True
# 4    781487        20             13     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0  -45.384 -66.368  1030.656
# 1  -85.888 -65.880   850.096
# 2 -102.480 -61.000   624.152
# 3  -96.624 -74.664   425.536
# 4 -126.392 -37.088   299.632
# dataLog_id_0020_nr_0014.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    841548        20             14     0       True       True       True  \
# 1    841548        20             14     0       True       True       True
# 2    841548        20             14     0       True       True       True
# 3    841548        20             14     0       True       True       True
# 4    841548        20             14     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -131.760 -155.672  1382.504
# 1 -203.008 -215.208  1285.392
# 2 -233.264 -149.816  1200.480
# 3 -201.544  -50.752  1161.928
# 4 -137.616   55.144  1179.984
# dataLog_id_0020_nr_0015.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    901538        20             15     0       True       True       True  \
# 1    901538        20             15     0       True       True       True
# 2    901538        20             15     0       True       True       True
# 3    901538        20             15     0       True       True       True
# 4    901538        20             15     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -211.792  -38.552  1639.680
# 1 -238.632   80.520  1655.784
# 2 -101.504  175.680  1636.264
# 3  182.512  198.128  1570.384
# 4  474.336  118.096  1518.656
# dataLog_id_0020_nr_0016.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    961530        20             16     0       True       True       True  \
# 1    961530        20             16     0       True       True       True
# 2    961530        20             16     0       True       True       True
# 3    961530        20             16     0       True       True       True
# 4    961530        20             16     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  281.088  173.240  1518.656
# 1  477.752   28.792  1433.744
# 2  475.312  -85.888  1407.880
# 3  275.232 -162.016  1454.240
# 4  -32.696 -134.200  1579.656
# dataLog_id_0020_nr_0017.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1021531        20             17     0       True       True       True  \
# 1   1021531        20             17     0       True       True       True
# 2   1021531        20             17     0       True       True       True
# 3   1021531        20             17     0       True       True       True
# 4   1021531        20             17     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0   22.448 -248.880  671.000
# 1 -219.112 -212.280  482.144
# 2 -369.416 -104.432  401.136
# 3 -376.248   35.624  375.272
# 4 -268.888  101.992  451.400
# dataLog_id_0020_nr_0018.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1081540        20             18     0       True       True       True  \
# 1   1081540        20             18     0       True       True       True
# 2   1081540        20             18     0       True       True       True
# 3   1081540        20             18     0       True       True       True
# 4   1081540        20             18     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0    0.976  -86.376  1476.200
# 1 -276.208 -108.336  1550.376
# 2 -443.592  -89.792  1656.272
# 3 -407.968  -41.968  1704.096
# 4 -241.560    9.760  1645.048
# dataLog_id_0020_nr_0019.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1141553        20             19     0       True       True       True  \
# 1   1141553        20             19     0       True       True       True
# 2   1141553        20             19     0       True       True       True
# 3   1141553        20             19     0       True       True       True
# 4   1141553        20             19     0       True       True       True
#
#      acc_x   acc_y    acc_z
# 0 -536.800 -48.800  493.856
# 1 -569.008 -72.224  528.504
# 2 -450.912 -50.752  596.824
# 3 -186.416 -32.696  657.336
# 4  115.656 -42.456  719.312
# dataLog_id_0020_nr_0020.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1201567        20             20     0       True       True       True  \
# 1   1201567        20             20     0       True       True       True
# 2   1201567        20             20     0       True       True       True
# 3   1201567        20             20     0       True       True       True
# 4   1201567        20             20     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  -95.648   60.024  1227.320
# 1 -127.368  -62.952  1194.624
# 2 -192.760 -129.808  1182.424
# 3 -223.992 -116.144  1185.840
# 4 -186.416  -25.864  1209.752
# dataLog_id_0020_nr_0021.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1261576        20             21     0       True       True       True  \
# 1   1261576        20             21     0       True       True       True
# 2   1261576        20             21     0       True       True       True
# 3   1261576        20             21     0       True       True       True
# 4   1261576        20             21     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0  235.704  29.280   976.000
# 1  154.696  -6.832  1016.992
# 2   83.936 -39.040  1094.096
# 3   12.688 -28.792  1207.312
# 4  -20.496  20.008  1300.032
# dataLog_id_0020_nr_0022.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1321586        20             22     0       True       True       True  \
# 1   1321586        20             22     0       True       True       True
# 2   1321586        20             22     0       True       True       True
# 3   1321586        20             22     0       True       True       True
# 4   1321586        20             22     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  159.088 -233.752  1314.672
# 1   -8.784 -147.376  1219.512
# 2 -103.944   -9.760  1075.552
# 3  -61.976   48.800   914.512
# 4   78.568   65.880   762.256
# dataLog_id_0020_nr_0023.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1381600        20             23     0       True       True       True  \
# 1   1381600        20             23     0       True       True       True
# 2   1381600        20             23     0       True       True       True
# 3   1381600        20             23     0       True       True       True
# 4   1381600        20             23     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0 -325.984 -243.512  301.096
# 1 -425.048 -123.464  160.552
# 2 -370.392  -12.688  110.776
# 3 -227.408   27.816  134.688
# 4  -73.688    4.880  217.648
# dataLog_id_0020_nr_0024.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1441607        20             24     0       True       True       True  \
# 1   1441607        20             24     0       True       True       True
# 2   1441607        20             24     0       True       True       True
# 3   1441607        20             24     0       True       True       True
# 4   1441607        20             24     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -368.928  -29.280   482.632
# 1 -505.568   74.664   572.424
# 2 -567.544  174.216   790.072
# 3 -458.232  178.608  1025.776
# 4 -189.832   64.904  1207.800
# dataLog_id_0021_nr_0000.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0      1332        21              0     0       True       True       True  \
# 1      1332        21              0     0       True       True       True
# 2      1332        21              0     0       True       True       True
# 3      1332        21              0     0       True       True       True
# 4      1332        21              0     0       True       True       True
#
#     acc_x   acc_y    acc_z
# 0 -45.872 -20.496  953.064
# 1 -36.112 -18.056  955.016
# 2 -26.352  -6.344  969.656
# 3 -11.224  -4.880  976.976
# 4 -12.200  -2.440  983.808
# dataLog_id_0021_nr_0001.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0     61358        21              1     0       True       True       True  \
# 1     61358        21              1     0       True       True       True
# 2     61358        21              1     0       True       True       True
# 3     61358        21              1     0       True       True       True
# 4     61358        21              1     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  180.072  391.864  1088.728
# 1  152.744  120.048   818.376
# 2   -4.880  -98.576   573.400
# 3 -222.040 -159.088   443.104
# 4 -375.272 -108.824   412.360
# dataLog_id_0021_nr_0002.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    121358        21              2     0       True       True       True  \
# 1    121358        21              2     0       True       True       True
# 2    121358        21              2     0       True       True       True
# 3    121358        21              2     0       True       True       True
# 4    121358        21              2     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0  125.416  287.432  887.672
# 1   31.232  179.584  757.864
# 2 -145.912   60.512  702.232
# 3 -291.336  -14.152  716.384
# 4 -309.880  -35.136  727.120
# dataLog_id_0021_nr_0003.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    181367        21              3     0       True       True       True  \
# 1    181367        21              3     0       True       True       True
# 2    181367        21              3     0       True       True       True
# 3    181367        21              3     0       True       True       True
# 4    181367        21              3     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0   80.520  -35.624  850.096
# 1 -122.976 -130.296  700.768
# 2 -264.496  -64.416  491.904
# 3 -325.984  -30.256  330.376
# 4 -336.720  -96.136  313.784
# dataLog_id_0021_nr_0004.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    241372        21              4     0       True       True       True  \
# 1    241372        21              4     0       True       True       True
# 2    241372        21              4     0       True       True       True
# 3    241372        21              4     0       True       True       True
# 4    241372        21              4     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -162.992 -174.216  1297.104
# 1 -133.224 -346.480  1102.880
# 2  -45.384 -607.560   942.816
# 3   34.648 -829.600   850.096
# 4    8.296 -765.184   824.232
# dataLog_id_0021_nr_0005.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    301441        21              5     0       True       True       True  \
# 1    301441        21              5     0       True       True       True
# 2    301441        21              5     0       True       True       True
# 3    301441        21              5     0       True       True       True
# 4    301441        21              5     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0  -12.200 -345.992  968.680
# 1 -138.592 -299.144  684.664
# 2 -322.568 -375.760  444.080
# 3 -469.456 -536.312  326.960
# 4 -454.816 -657.824  304.512
# dataLog_id_0021_nr_0006.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    361397        21              6     0       True       True       True  \
# 1    361397        21              6     0       True       True       True
# 2    361397        21              6     0       True       True       True
# 3    361397        21              6     0       True       True       True
# 4    361397        21              6     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -143.960  239.608  1127.280
# 1  -99.064  256.200  1018.456
# 2  -21.472  280.600  1021.872
# 3  144.448  341.600  1108.248
# 4  290.360  453.840  1206.824
# dataLog_id_0021_nr_0007.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    421462        21              7     0       True       True       True  \
# 1    421462        21              7     0       True       True       True
# 2    421462        21              7     0       True       True       True
# 3    421462        21              7     0       True       True       True
# 4    421462        21              7     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0  140.056  366.000  927.688
# 1   77.104  397.232  785.680
# 2  -35.624  366.976  685.640
# 3 -176.656  217.160  668.072
# 4 -246.928   74.176  745.664
# dataLog_id_0021_nr_0008.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    481460        21              8     0       True       True       True  \
# 1    481460        21              8     0       True       True       True
# 2    481460        21              8     0       True       True       True
# 3    481460        21              8     0       True       True       True
# 4    481460        21              8     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  261.568  158.112   925.736
# 1  105.896  216.184   940.376
# 2 -105.408  310.856   969.168
# 3 -207.400  332.328  1001.376
# 4 -169.824  286.944  1074.576
# dataLog_id_0021_nr_0009.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    541459        21              9     0       True       True       True  \
# 1    541459        21              9     0       True       True       True
# 2    541459        21              9     0       True       True       True
# 3    541459        21              9     0       True       True       True
# 4    541459        21              9     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  -30.744  464.576  1294.664
# 1  118.584  558.272  1473.272
# 2  214.720  530.944  1559.160
# 3  332.328  495.808  1490.352
# 4  386.496  386.984  1280.024
# dataLog_id_0021_nr_0010.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    601463        21             10     0       True       True       True  \
# 1    601463        21             10     0       True       True       True
# 2    601463        21             10     0       True       True       True
# 3    601463        21             10     0       True       True       True
# 4    601463        21             10     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -310.856 -222.040   463.600
# 1 -305.000 -360.144   726.144
# 2 -163.968 -556.808  1034.072
# 3   57.584 -713.456  1357.616
# 4  183.000 -664.168  1640.168
# dataLog_id_0021_nr_0011.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    661464        21             11     0       True       True       True  \
# 1    661464        21             11     0       True       True       True
# 2    661464        21             11     0       True       True       True
# 3    661464        21             11     0       True       True       True
# 4    661464        21             11     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0   22.448  250.832  780.312
# 1  -30.256   97.112  567.056
# 2 -116.144    7.808  411.384
# 3 -163.480  -64.416  347.456
# 4 -206.424 -128.832  383.568
# dataLog_id_0021_nr_0012.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    721463        21             12     0       True       True       True  \
# 1    721463        21             12     0       True       True       True
# 2    721463        21             12     0       True       True       True
# 3    721463        21             12     0       True       True       True
# 4    721463        21             12     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  113.704  446.520  1196.576
# 1  262.544  527.040  1370.792
# 2  282.552  549.488  1467.904
# 3  173.728  446.520  1573.800
# 4   26.352  275.720  1671.888
# dataLog_id_0021_nr_0013.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    781465        21             13     0       True       True       True  \
# 1    781465        21             13     0       True       True       True
# 2    781465        21             13     0       True       True       True
# 3    781465        21             13     0       True       True       True
# 4    781465        21             13     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0 -290.848 -26.352  1303.936
# 1 -133.712  -4.880  1189.744
# 2   58.072 -15.128   995.520
# 3  193.248 -43.920   857.904
# 4  168.360  27.328   813.008
# dataLog_id_0021_nr_0014.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    841473        21             14     0       True       True       True  \
# 1    841473        21             14     0       True       True       True
# 2    841473        21             14     0       True       True       True
# 3    841473        21             14     0       True       True       True
# 4    841473        21             14     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  -99.552  392.352  1042.368
# 1  -79.056  340.624  1110.200
# 2    3.904  223.504  1224.392
# 3  131.272  100.528  1329.312
# 4  117.120  -36.600  1392.752
# dataLog_id_0021_nr_0015.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    901482        21             15     0       True       True       True  \
# 1    901482        21             15     0       True       True       True
# 2    901482        21             15     0       True       True       True
# 3    901482        21             15     0       True       True       True
# 4    901482        21             15     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0   82.472  289.872  1210.728
# 1  -92.232  264.496  1332.728
# 2 -137.128  193.736  1410.808
# 3 -104.920  124.440  1390.312
# 4  -18.544   11.224  1255.136
# dataLog_id_0021_nr_0016.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    961497        21             16     0       True       True       True  \
# 1    961497        21             16     0       True       True       True
# 2    961497        21             16     0       True       True       True
# 3    961497        21             16     0       True       True       True
# 4    961497        21             16     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -141.520  499.712  1252.696
# 1 -294.264  553.392  1221.952
# 2 -197.640  504.104  1042.368
# 3   -8.296  399.184   792.512
# 4   33.184  203.496   590.480
# dataLog_id_0021_nr_0017.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1021506        21             17     0       True       True       True  \
# 1   1021506        21             17     0       True       True       True
# 2   1021506        21             17     0       True       True       True
# 3   1021506        21             17     0       True       True       True
# 4   1021506        21             17     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  284.016  -86.864   802.760
# 1  454.816  100.040   964.776
# 2  379.664  282.064  1069.208
# 3   54.656  426.512  1113.616
# 4 -322.080  564.616  1068.720
# dataLog_id_0021_nr_0018.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1081519        21             18     0       True       True       True  \
# 1   1081519        21             18     0       True       True       True
# 2   1081519        21             18     0       True       True       True
# 3   1081519        21             18     0       True       True       True
# 4   1081519        21             18     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0   13.664  442.616  1086.288
# 1   17.080  422.608  1111.176
# 2   72.712  381.616  1065.792
# 3  183.000  291.336   948.672
# 4  103.944  189.832   828.624
# dataLog_id_0021_nr_0019.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1141524        21             19     0       True       True       True  \
# 1   1141524        21             19     0       True       True       True
# 2   1141524        21             19     0       True       True       True
# 3   1141524        21             19     0       True       True       True
# 4   1141524        21             19     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -141.520  241.072  1459.608
# 1   20.496   24.400  1522.072
# 2  139.568  -73.200  1566.968
# 3  120.536  -23.424  1564.040
# 4   46.360   73.688  1484.008
# dataLog_id_0021_nr_0020.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1201534        21             20     0       True       True       True  \
# 1   1201534        21             20     0       True       True       True
# 2   1201534        21             20     0       True       True       True
# 3   1201534        21             20     0       True       True       True
# 4   1201534        21             20     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0  124.440 -371.856  866.688
# 1  119.072 -479.216  672.464
# 2  -25.864 -482.144  513.864
# 3 -332.328 -445.544  422.120
# 4 -570.960 -447.008  401.624
# dataLog_id_0021_nr_0021.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1261550        21             21     0       True       True       True  \
# 1   1261550        21             21     0       True       True       True
# 2   1261550        21             21     0       True       True       True
# 3   1261550        21             21     0       True       True       True
# 4   1261550        21             21     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -266.448 -237.656  1019.920
# 1 -289.872 -337.208  1210.728
# 2 -149.328 -471.408  1409.344
# 3   66.856 -570.472  1571.848
# 4  198.616 -454.816  1627.968
# dataLog_id_0021_nr_0022.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0   1321563        21             22     0       True       True       True  \
# 1   1321563        21             22     0       True       True       True
# 2   1321563        21             22     0       True       True       True
# 3   1321563        21             22     0       True       True       True
# 4   1321563        21             22     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  122.976  -98.576   673.928
# 1  185.928 -294.752   914.024
# 2  145.912 -324.520  1170.224
# 3    5.368 -278.160  1401.536
# 4 -116.632 -270.352  1569.408
# dataLog_id_0022_nr_0000.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0      1333        22              0     0       True       True       True  \
# 1      1333        22              0     0       True       True       True
# 2      1333        22              0     0       True       True       True
# 3      1333        22              0     0       True       True       True
# ...
# 2 -223.016  -72.712  1321.992
# 3 -243.024  -70.760  1299.056
# 4 -136.640  -28.792  1212.680
# dataLog_id_0025_nr_0009.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    541438        25              9     0       True       True       True  \
# 1    541438        25              9     0       True       True       True
# 2    541438        25              9     0       True       True       True
# 3    541438        25              9     0       True       True       True
# 4    541438        25              9     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0 -286.456  179.584   678.320
# 1  -93.696  218.624   763.720
# 2  163.968  163.968   832.528
# 3  365.512   49.776   903.776
# 4  405.528 -100.528  1009.184
# dataLog_id_0025_nr_0010.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    601439        25             10     0       True       True       True  \
# 1    601439        25             10     0       True       True       True
# 2    601439        25             10     0       True       True       True
# 3    601439        25             10     0       True       True       True
# 4    601439        25             10     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  350.872  105.896  1252.696
# 1  273.280   38.552  1317.112
# 2  129.808  -33.672  1353.712
# 3  -34.160  -70.272  1324.920
# 4 -167.872  -98.088  1238.056
# dataLog_id_0025_nr_0011.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    661443        25             11     0       True       True       True  \
# 1    661443        25             11     0       True       True       True
# 2    661443        25             11     0       True       True       True
# 3    661443        25             11     0       True       True       True
# 4    661443        25             11     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0  -73.200 -43.920   739.808
# 1 -250.832 -20.008   881.816
# 2 -299.144  14.152  1058.960
# 3 -222.528  53.680  1213.656
# 4  -66.368  52.704  1318.088
# dataLog_id_0025_nr_0012.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    721452        25             12     0       True       True       True  \
# 1    721452        25             12     0       True       True       True
# 2    721452        25             12     0       True       True       True
# 3    721452        25             12     0       True       True       True
# 4    721452        25             12     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0  121.512 -54.168  1286.368
# 1   81.984 -34.648  1180.960
# 2   76.616  11.224  1058.960
# 3   58.560  18.056   920.368
# 4   19.032  -2.928   765.184
# dataLog_id_0025_nr_0013.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    781458        25             13     0       True       True       True  \
# 1    781458        25             13     0       True       True       True
# 2    781458        25             13     0       True       True       True
# 3    781458        25             13     0       True       True       True
# 4    781458        25             13     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  154.208  -20.496  1402.024
# 1  180.560   79.544  1561.112
# 2  191.296  136.640  1626.016
# 3  182.512  141.032  1575.264
# 4  193.736   80.520  1412.760
# dataLog_id_0025_nr_0014.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    841467        25             14     0       True       True       True  \
# 1    841467        25             14     0       True       True       True
# 2    841467        25             14     0       True       True       True
# 3    841467        25             14     0       True       True       True
# 4    841467        25             14     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  248.392 -110.288  1156.560
# 1  438.712  -86.376  1333.216
# 2  468.968  -46.360  1514.752
# 3  345.504   20.008  1663.592
# 4  128.832   97.600  1734.352
# dataLog_id_0025_nr_0015.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    901475        25             15     0       True       True       True  \
# 1    901475        25             15     0       True       True       True
# 2    901475        25             15     0       True       True       True
# 3    901475        25             15     0       True       True       True
# 4    901475        25             15     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0  -13.664 -107.360  736.392
# 1  -81.008  -95.160  629.032
# 2 -132.736  -14.152  605.608
# 3 -144.936   36.112  678.808
# 4 -135.664   53.680  831.552
# dataLog_id_0025_nr_0016.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    961485        25             16     0       True       True       True  \
# 1    961485        25             16     0       True       True       True
# 2    961485        25             16     0       True       True       True
# 3    961485        25             16     0       True       True       True
# 4    961485        25             16     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0 -415.288 -92.720   902.312
# 1 -447.496 -40.992   948.184
# 2 -338.672 -39.040  1014.552
# 3 -133.712 -27.816  1052.128
# 4   78.568   9.272  1052.616
# dataLog_id_0026_nr_0000.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0      1255        26              0     0       True       True       True  \
# 1      1255        26              0     0       True       True       True
# 2      1255        26              0     0       True       True       True
# 3      1255        26              0     0       True       True       True
# 4      1255        26              0     0       True       True       True
#
#     acc_x   acc_y    acc_z
# 0 -39.528  -9.272  976.488
# 1 -33.184 -21.472  988.200
# 2 -23.424 -24.400  979.904
# 3 -12.200 -30.256  981.368
# 4  -7.320 -31.720  973.560
# dataLog_id_0026_nr_0001.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0     61300        26              1     0       True       True       True  \
# 1     61300        26              1     0       True       True       True
# 2     61300        26              1     0       True       True       True
# 3     61300        26              1     0       True       True       True
# 4     61300        26              1     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  138.104 -301.584  1043.344
# 1  249.368 -188.856  1230.248
# 2  270.840  -68.320  1363.960
# 3  251.320  -33.672  1460.096
# 4  228.384  -66.368  1525.000
# dataLog_id_0026_nr_0002.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    121308        26              2     0       True       True       True  \
# 1    121308        26              2     0       True       True       True
# 2    121308        26              2     0       True       True       True
# 3    121308        26              2     0       True       True       True
# 4    121308        26              2     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0 -196.176  15.616  1074.088
# 1 -223.992 -34.160  1135.088
# 2 -118.096 -70.760  1206.336
# 3   34.648 -75.640  1278.560
# 4  198.616 -48.312  1315.648
# dataLog_id_0026_nr_0003.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    181298        26              3     0       True       True       True  \
# 1    181298        26              3     0       True       True       True
# 2    181298        26              3     0       True       True       True
# 3    181298        26              3     0       True       True       True
# 4    181298        26              3     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0   -3.416 -70.272  1168.272
# 1  182.024 -56.120   965.264
# 2  312.808  -6.344   761.280
# 3  286.944  41.480   585.600
# 4   74.176  58.072   525.576
# dataLog_id_0026_nr_0004.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    241299        26              4     0       True       True       True  \
# 1    241299        26              4     0       True       True       True
# 2    241299        26              4     0       True       True       True
# 3    241299        26              4     0       True       True       True
# 4    241299        26              4     0       True       True       True
#
#      acc_x   acc_y    acc_z
# 0 -157.624   3.416  798.856
# 1 -259.128  81.008  672.464
# 2 -316.712  73.688  590.480
# 3 -352.336  13.176  584.624
# 4 -359.168 -27.816  661.240
# dataLog_id_0026_nr_0005.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    301348        26              5     0       True       True       True  \
# 1    301348        26              5     0       True       True       True
# 2    301348        26              5     0       True       True       True
# 3    301348        26              5     0       True       True       True
# 4    301348        26              5     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0   39.040  67.832  1181.448
# 1  -23.912   5.368   976.976
# 2 -195.200 -14.640   825.696
# 3 -436.272  -5.856   776.896
# 4 -592.920 -38.552   868.152
# dataLog_id_0026_nr_0006.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    361322        26              6     0       True       True       True  \
# 1    361322        26              6     0       True       True       True
# 2    361322        26              6     0       True       True       True
# 3    361322        26              6     0       True       True       True
# 4    361322        26              6     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0   64.416 -175.680  1016.016
# 1   26.840  -61.000   970.632
# 2 -121.024   27.328   930.616
# 3 -256.688   21.472   943.304
# 4 -332.816  -18.544  1018.944
# dataLog_id_0026_nr_0007.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    421383        26              7     0       True       True       True  \
# 1    421383        26              7     0       True       True       True
# 2    421383        26              7     0       True       True       True
# 3    421383        26              7     0       True       True       True
# 4    421383        26              7     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  177.144  156.648  1284.416
# 1  251.320  101.992  1300.520
# 2  177.144   25.376  1339.072
# 3   86.864  -52.704  1406.416
# 4   48.312 -129.808  1476.200
# dataLog_id_0026_nr_0008.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    481371        26              8     0       True       True       True  \
# 1    481371        26              8     0       True       True       True
# 2    481371        26              8     0       True       True       True
# 3    481371        26              8     0       True       True       True
# 4    481371        26              8     0       True       True       True
#
#      acc_x   acc_y     acc_z
# 0 -490.440   3.904   919.392
# 1 -185.440 -22.936   990.640
# 2  155.672 -12.200  1040.416
# 3  390.400  10.736  1087.752
# 4  451.888  21.472  1169.736
# dataLog_id_0026_nr_0009.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    541361        26              9     0       True       True       True  \
# 1    541361        26              9     0       True       True       True
# 2    541361        26              9     0       True       True       True
# 3    541361        26              9     0       True       True       True
# 4    541361        26              9     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  199.592 -148.352  1503.528
# 1   17.080  -63.440  1492.304
# 2 -182.512    7.320  1435.696
# 3 -242.048   25.376  1330.288
# 4 -126.392   30.744  1151.680
# dataLog_id_0026_nr_0010.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    601356        26             10     0       True       True       True  \
# 1    601356        26             10     0       True       True       True
# 2    601356        26             10     0       True       True       True
# 3    601356        26             10     0       True       True       True
# 4    601356        26             10     0       True       True       True
#
#     acc_x   acc_y     acc_z
# 0 -65.392 -67.832  1006.256
# 1   2.440 -14.640  1082.384
# 2  -2.440  43.920  1133.624
# 3   0.976  68.320  1152.168
# 4   9.272  47.824  1105.808
# dataLog_id_0026_nr_0011.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    661368        26             11     0       True       True       True  \
# 1    661368        26             11     0       True       True       True
# 2    661368        26             11     0       True       True       True
# 3    661368        26             11     0       True       True       True
# 4    661368        26             11     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  -18.544  -48.312  1096.048
# 1  127.856  -54.168  1102.880
# 2  194.712  -74.664  1088.240
# 3   90.768  -11.224  1072.624
# 4 -120.536  101.992  1068.232
# dataLog_id_0026_nr_0012.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    721376        26             12     0       True       True       True  \
# 1    721376        26             12     0       True       True       True
# 2    721376        26             12     0       True       True       True
# 3    721376        26             12     0       True       True       True
# 4    721376        26             12     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  229.360  245.952  1601.616
# 1  122.976  200.568  1397.144
# 2  101.992   41.480  1172.664
# 3  148.352 -141.032   931.592
# 4  184.464 -209.840   711.992
# dataLog_id_0026_nr_0013.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    781385        26             13     0       True       True       True  \
# 1    781385        26             13     0       True       True       True
# 2    781385        26             13     0       True       True       True
# 3    781385        26             13     0       True       True       True
# 4    781385        26             13     0       True       True       True
#
#      acc_x    acc_y    acc_z
# 0 -198.128 -158.600  832.528
# 1 -270.840  -36.112  807.152
# 2 -226.432    2.928  770.552
# 3 -150.792  -53.192  732.000
# 4 -104.432 -158.112  719.800
# dataLog_id_0026_nr_0014.TXT
#   timestamp logger_id logger_file_nr label flag_acc_x flag_acc_y flag_acc_z
# 0    841400        26             14     0       True       True       True  \
# 1    841400        26             14     0       True       True       True
# 2    841400        26             14     0       True       True       True
# 3    841400        26             14     0       True       True       True
# 4    841400        26             14     0       True       True       True
#
#      acc_x    acc_y     acc_z
# 0  456.768  195.200  1265.872
# 1  183.976  282.064  1032.120
# 2 -142.984  213.744   805.200
# 3 -334.280   48.800   621.224
# 4 -333.304  -97.600   479.704

# %%
print(main_df.to_markdown())

# %%
pp.pprint(dataset_parameters_dict)
# Out:
# {   11: {   'dictionary_type': 'dataset-from-logger_id',
#             'labels': {   'description': 'dataset-labels',
#                           'dictionary_type': 'dataset_parameter',
#                           'value': {   0: {   'description': 'Label-0',
#                                               'dictionary_type': 'label',
#                                               'nr_files': 8,
#                                               'value_type': 'dictionary-of-label',
#                                               'value_unit': ''},
#                                        1: {   'description': 'Label-1',
#                                               'dictionary_type': 'label',
#                                               'nr_files': 0,
#                                               'value_type': 'dictionary-of-label',
#                                               'value_unit': ''},
#                                        2: {   'description': 'Label-2',
#                                               'dictionary_type': 'label',
#                                               'nr_files': 0,
#                                               'value_type': 'dictionary-of-label',
#                                               'value_unit': ''}},
#                           'value_type': 'dictionary-of-the-labels',
#                           'value_unit': ''},
#             'nr_files': {   'description': 'number-of-files',
#                             'dictionary_type': 'dataset_parameter',
#                             'value': 8,
#                             'value_type': 'int',
#                             'value_unit': ''},
#             'sources': {   'dictionary_type': 'dataset_parameter',
#                            'value': {   'acc_x': {   'dictionary_type': 'source',
#                                                      'samples_nr': {   'description': 'number-of-samples',
#                                                                        'dictionary_type': 'source_parameter',
#                                                                        'value': 3216000,
#                                                                        'value_type': 'int',
#                                                                        'value_unit': ''},
#                                                      'samples_nr_bytes': {   'description': 'number-of-bytes-of-each-sample',
#                                                                              'dictionary_type': 'source_parameter',
#                                                                              'value': -1,
#                                                                              'value_type': 'int',
#                                                                              'value_unit': 'bytes'},
#                                                      'sampling_frequency_real': {   'description': 'real-sampling-frequency-of-the-source',
#                                                                                     'dictionary_type': 'source_parameter',
#                                                                                     'value': 6706.248675,
#                                                                                     'value_type': 'int',
#                                                                                     'value_unit': '[Hz]'},
#                                                      'sampling_frequency_set': {   'description': 'sampling-frequency-set-in-the-logger',
#                                                                                    'dictionary_type': 'source_parameter',
#                                                                                    'value': 6667,
#                                                                                    'value_type': 'int',
#                                                                                    'value_unit': '[Hz]'},
#                                                      'scale': {   'description': 'scale-of-the-source',
#                                                                   'dictionary_type': 'source_parameter',
#                                                                   'value': 16,
#                                                                   'value_type': 'int',
#                                                                   'value_unit': '[mg]'},
#                                                      'value_type': 'dictionary-of-source '
#                                                                    'parameters',
#                                                      'value_unit': '[mg]'},
#                                         'acc_y': {   'dictionary_type': 'source',
#                                                      'samples_nr': {   'description': 'number-of-samples',
#                                                                        'dictionary_type': 'source_parameter',
#                                                                        'value': 3216000,
#                                                                        'value_type': 'int',
#                                                                        'value_unit': ''},
#                                                      'samples_nr_bytes': {   'description': 'number-of-bytes-of-each-sample',
#                                                                              'dictionary_type': 'source_parameter',
#                                                                              'value': -1,
#                                                                              'value_type': 'int',
#                                                                              'value_unit': 'bytes'},
#                                                      'sampling_frequency_real': {   'description': 'real-sampling-frequency-of-the-source',
#                                                                                     'dictionary_type': 'source_parameter',
#                                                                                     'value': 6706.248675,
#                                                                                     'value_type': 'int',
#                                                                                     'value_unit': '[Hz]'},
#                                                      'sampling_frequency_set': {   'description': 'sampling-frequency-set-in-the-logger',
#                                                                                    'dictionary_type': 'source_parameter',
#                                                                                    'value': 6667,
#                                                                                    'value_type': 'int',
#                                                                                    'value_unit': '[Hz]'},
#                                                      'scale': {   'description': 'scale-of-the-source',
#                                                                   'dictionary_type': 'source_parameter',
#                                                                   'value': 16,
#                                                                   'value_type': 'int',
#                                                                   'value_unit': '[mg]'},
#                                                      'value_type': 'dictionary-of-source '
#                                                                    'parameters',
#                                                      'value_unit': '[mg]'},
#                                         'acc_z': {   'dictionary_type': 'source',
#                                                      'samples_nr': {   'description': 'number-of-samples',
#                                                                        'dictionary_type': 'source_parameter',
#                                                                        'value': 3216000,
#                                                                        'value_type': 'int',
#                                                                        'value_unit': ''},
#                                                      'samples_nr_bytes': {   'description': 'number-of-bytes-of-each-sample',
#                                                                              'dictionary_type': 'source_parameter',
#                                                                              'value': -1,
#                                                                              'value_type': 'int',
#                                                                              'value_unit': 'bytes'},
#                                                      'sampling_frequency_real': {   'description': 'real-sampling-frequency-of-the-source',
#                                                                                     'dictionary_type': 'source_parameter',
#                                                                                     'value': 6706.248675,
#                                                                                     'value_type': 'int',
#                                                                                     'value_unit': '[Hz]'},
#                                                      'sampling_frequency_set': {   'description': 'sampling-frequency-set-in-the-logger',
#                                                                                    'dictionary_type': 'source_parameter',
#                                                                                    'value': 6667,
#                                                                                    'value_type': 'int',
#                                                                                    'value_unit': '[Hz]'},
#                                                      'scale': {   'description': 'scale-of-the-source',
#                                                                   'dictionary_type': 'source_parameter',
#                                                                   'value': 16,
#                                                                   'value_type': 'int',
#                                                                   'value_unit': '[mg]'},
#                                                      'value_type': 'dictionary-of-source '
#                                                                    'parameters',
#                                                      'value_unit': '[mg]'}},
#                            'value_type': 'dictionary-of-dictionaries-sources',
#                            'value_unit': ''},
#             'total_measured_time': {   'description': 'total-measured-time-of-the-dataset',
#                                        'dictionary_type': 'dataset_parameter',
#                                        'value': 479.553,
#                                        'value_type': 'int',
#                                        'value_unit': 'seconds'},
#             'value_type': 'dictionary'},
#     'id_vars': [   'sample_index',
#                    'logger_id',
#                    'label',
#                    'timestamp',
#                    'logger_file_nr',
#                    'flag_acc_y',
#                    'flag_acc_z',
#                    'flag_acc_x'],
#     'value_vars': ['acc_y', 'acc_z', 'acc_x']}

# %%
bin_file_pointer.close()
